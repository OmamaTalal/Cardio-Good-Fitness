# %% [markdown]
# # Exploratory Data Analysis for Cardio Good Fitness Data

# %% [markdown]
# # Context
#
# ### Explore this dataset to identify differences between the customers of each product. Also to explore relationships between the different attributes of the customers.
#
# # Data Description:¶
#
# The data is about customers of the treadmill product(s) of a retail store called Cardio Good Fitness. It contains the following variables:
#
#
# **Product** - The model no. of the treadmill
#
# **Age** -  Age of the customer in no of years
#
# **Gender** - Gender of the customer
#
# **Education** - Education of the customer in no. of years
#
# **Marital Status**- Marital status of the customer
#
# **Usage - Avg**. # times the customer wants to use the treadmill every week
#
# **Fitness** - Self rated fitness score of the customer (5 - very fit, 1 - very unfit)
#
# **Income** - Income of the customer
#
# **Miles**- Miles that a customer expects to run

# %%
#improt google colab drive library to connect it with this notebook 
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# from os library change the directory to the data place directory  to read the data
import os
os.chdir('/content/drive/My Drive/colab/')

# %% [markdown]
# **Importing necessary libraries**

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Command to tell Python to actually display the graphs
# %matplotlib inline

# %% [markdown]
# **Importing the dataset**

# %%
data = pd.read_csv('CardioGoodFitness.csv')

# %% [markdown]
# **Understand the shape of the dataset**

# %%
# checking shape of the data
print("There are", data.shape[0], 'rows and', data.shape[1], "columns.")
# Out:
# There are 180 rows and 9 columns.

# %% [markdown]
# **View the first and last 5 rows of the dataset**

# %%
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
data.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %% [markdown]
# **Check the data types of the columns for the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# *  There are 6 numerical data type
# *  There are 3 objects ( Strings ) caterogical data type
# *  There is no data type need to convert its datatype into
#    different datatype
#
#
# ---

# %% [markdown]
# **Checking for missing values in the data**

# %%
data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# *   There is no any missing values or empty cells in the data set
# *   No droping operation will be applied
#
#
#
# ---

# %% [markdown]
# **Checking for duplicate entries in the data**

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is 0 duplicate entries in the data. No removing operation will be applied
#
#
# ---

# %% [markdown]
# **Let's check the statistical summary of the data.**

# %%
data.describe(include='all').T
# Out:
#                count unique        top freq          mean           std  \
# Product          180      3      TM195   80           NaN           NaN
# Age            180.0    NaN        NaN  NaN     28.788889      6.943498
# Gender           180      2       Male  104           NaN           NaN
# Education      180.0    NaN        NaN  NaN     15.572222      1.617055
# MaritalStatus    180      2  Partnered  107           NaN           NaN
# Usage          180.0    NaN        NaN  NaN      3.455556      1.084797
# Fitness        180.0    NaN        NaN  NaN      3.311111      0.958869
# Income         180.0    NaN        NaN  NaN  53719.577778  16506.684226
# Miles          180.0    NaN        NaN  NaN    103.194444     51.863605
#
#                    min       25%      50%      75%       max
# Product            NaN       NaN      NaN      NaN       NaN
# Age               18.0      24.0     26.0     33.0      50.0
# Gender             NaN       NaN      NaN      NaN       NaN
# ...

# %% [markdown]
# *   The minimum **age** for the customers who are using the products is 18. The maximum **age** for the customers who are using the products is 50.
# *   The most used **product** is TM195. It used in 80 rows.
# *   The average of **usage** is about 3 times per week
# *   How **fitness** the customers are has an average of 3 out of 5 which is more than the half of the customers number
# *   On average the customer **incomes** are 53719.57. The median **incomes** are 50596.5. There is a huge difference between the maximum value and the 75% percentile of the data which indicates there might be outliers present in this column.
# *   **Gender** most of the customers are males. There are 104 males in the data set.
# *   **Miles** 75% percentile of the customers run for 114.75 miles. On average they run for 103.There is a huge difference between the maximum value and the 75% percentile of the data which indicates there might be outliers present in this colum.
# *   **MaritalStatus**  most frequent marital status is partnered.
# *   **Education**  On average the education years are 15. The median are 16. There is a difference between the maximum value and the 75% percentile of the data which indicates there might be outliers present in this column.
#
#
# ---

# %% [markdown]
# Income affect the buying for sport tools. Let us make an assumption high income means strong buyer.
# Customers who have unique income may affect the assumption wether it is lowest or highest.
#
# Check how many customers have unique income..

# %%
data['Income'].unique() # unique function get the uniquness of the data in a specific column
# Out:
# array([ 29562,  31836,  30699,  32973,  35247,  37521,  36384,  38658,
#         40932,  34110,  39795,  42069,  44343,  45480,  46617,  48891,
#         53439,  43206,  52302,  51165,  50028,  54576,  68220,  55713,
#         60261,  67083,  56850,  59124,  61398,  57987,  64809,  47754,
#         65220,  62535,  48658,  54781,  48556,  58516,  53536,  61006,
#         57271,  52291,  49801,  62251,  64741,  70966,  75946,  74701,
#         69721,  83416,  88396,  90886,  92131,  77191,  52290,  85906,
#        103336,  99601,  89641,  95866, 104581,  95508])

# %%
data['Income'].max() # max function get the maximum data number for a specific numerical column
# Out:
# 104581

# %%
data['Income'].min() # min function get the minimum data number for a specific numerical column
# Out:
# 29562

# %%
data['Income'].nunique()
# Out:
# 62

# %% [markdown]
# We have 62 unique income out of 180 rows. That means it is about 21% percent of the customers have unique income (not a usual income). Is that will affect the data. I think it will not affect the analysis of the data. The maximum income in the data set was 104581 and the minimum income was 29562. That indicates that the level of the socity is work class and mediume or less than medium level of rich.

# %% [markdown]
# **Let's check the count and percentage of categorical levels in each column in categorical data**

# %%
# Making a list of all categorical variables
cat_cols =  ['Product', 'Gender', 'MaritalStatus']

# Printing the count of unique categorical levels in each column
for column in cat_cols:
    print(data[column].value_counts())
    print("-" * 50)
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64
# --------------------------------------------------
# Male      104
# Female     76
# Name: Gender, dtype: int64
# --------------------------------------------------
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64
# --------------------------------------------------

# %% [markdown]
# *   The most used product in this data set is TM195
# *   Most of the customers are Males. They are more than Female by 28.
# *   Most of the customers are Partenered. They are more than single by 34.
#
# So or anlysis is going to be focused on Partenred, male and TM195.

# %%
# Printing the percentage of unique categorical levels in each column
for column in cat_cols:
    print(data[column].value_counts(normalize=True))
    print("-" * 50)
# Out:
# TM195    0.444444
# TM498    0.333333
# TM798    0.222222
# Name: Product, dtype: float64
# --------------------------------------------------
# Male      0.577778
# Female    0.422222
# Name: Gender, dtype: float64
# --------------------------------------------------
# Partnered    0.594444
# Single       0.405556
# Name: MaritalStatus, dtype: float64
# --------------------------------------------------

# %% [markdown]
# Observations
#
# *  Highest uesed product is in TM195 (used 44% times in the data), followed by TM498 (used 33% times in the data). And the minium used product it is TM798. It got the percentage of 22%.
# *  Most of the customers (104 or 57%) are males, followed by 76 or 42% femals.
# *  59% of the customers are partnered followed by 40% single. This shows that our analysis will be biased towards males and females because the percent of the data of the gender is not about specific gender.
#
#
#
# ---

# %% [markdown]
# # Univariate Analysis
#
# Univariate data analysis plots visualizations that help us recoginesed the descriptive summary of a specific data variable in the data set. These visualizations enhance our understanding of the position/situation of observations, its distribution, and scattering of the variable in the data set.
#
# We can check the distribution of observations by plotting Histograms and Boxplots.
#
# A histogram takes as input a numeric variable only. The variable is cut into several bins, and the number of observations per bin is represented by the height of the bar.
#
# A boxplot visually shows skewness through displaying the data quartiles (or percentiles) upper and lower, averages ,  minimum score, median, maximum score and the outliers.
#
# **Let's check the distribution for numerical columns.**

# %% [markdown]
# **Observations on Income**

# %%
sns.displot(data=data,x='Income',kind='kde')
plt.show()
sns.boxplot(data=data,x='Income')
plt.show()

# %% [markdown]
# *  The distribution is a little bit skewed towards right.
# *  There are many outliers present in this column.
# Values above 78k are being represented as outliers in the boxplot, indicating there there are many customers at least have income low than 60k per year and above 43k per year.
# *  The income median is 50K.
#
#
# ---

# %% [markdown]
# **Observations on Age**
#
# I am going to use displot because age is continous variable. The type of the distribution will be kde (Kernal Density Estimation). It is a way to estimate the probability density for continous random variable.

# %%
sns.displot(data=data,x='Age',kind='kde')
plt.show()
sns.boxplot(data=data,x='Age')
plt.show()

# %% [markdown]
# *   The distribution is skewed towards the right.
# *   There are three outliers present in this column. The distribution indicates that the age outliers above 46 years.
# *   The median of age is 26 years old.

# %% [markdown]
# **Observations on Education**

# %% [markdown]
# I am going to use histogram here with columns ( not the line histogram ) because it seems that there a gap between the number of years and the number of educated years will be represended well if we use the column histogram and also will use the kde type.

# %%
sns.displot(data=data, x = 'Education')
sns.displot(data=data,x='Education', kind='kde')
plt.show()
sns.boxplot(data=data,x='Education')
plt.show()

# %% [markdown]
# *   The histogram shows that the most frequent number of the education years is about 16 education years. And then 14 education years.
# *   The box plot shows that the years more than 18 is outliers and we have here 2 outliers points.
# *   The diagrams shows that the graph of number of educational years is skweed to the right a little bit. And the density is on the left side.

# %% [markdown]
# **Observations on Fitness**

# %% [markdown]
# Fitness data is not a continous varaible. So the best fit diagram for it is histograms with columns not with kind kde. Let us check how good the customers ranked their fitness.

# %%
sns.histplot(data=data,x='Fitness')
plt.show()
sns.boxplot(data=data,x='Fitness')
plt.show()

# %% [markdown]
# * Most of the customers put their fitness on 3 out of 5. That means most of the customer moderate level of fitness.
# * The outliers from the box plots here for the cutomers who rank their fitness on 1 out of 5 or unfit.
# * The diagram a little left skweed.
# * The density of the fitness is from 3 to 4.

# %% [markdown]
# **Observations on Usage**

# %% [markdown]
# Usage is not a continous numerical variable. It is a varaible in the data set that indicate how many times you use the product within the week.
# So Histogram with columns is the best fit for this analysis.

# %%
sns.histplot(data=data,x='Usage')
plt.show()
sns.boxplot(data=data,x='Usage')
plt.show()

# %% [markdown]
# * The histogram diagram shows that most of the customers use their product 3 times per week. Which is expected from the fitness histogram diagram most of the customers ranked thier fitness 3 out of five.
# * The histogram shows that the data is right skweed.
# * The 6 and 7 usage are indicated as outliers.
# * The box plot show that the less usage time is 2.

# %% [markdown]
# **Observations on Miles**

# %% [markdown]
# Miles data is continous. So we can use the histogram with column and with kind of kde. Let us check the univariate analysis for this attribute.

# %%
sns.histplot(data=data,x='Miles')
sns.displot(data=data,x='Miles', kind='kde')
plt.show()
sns.boxplot(data=data,x='Miles')
plt.show()

# %% [markdown]
# * Miles is right skweed.
# * Miles variable has many outliers. The outliers is considered to be more than 190 miles.
# * The median is approximatly 90.
# * Most of the customers runs from 60 to 120 miles.

# %% [markdown]
# # Bivariate Analysis
#
# Bivariate analysis is the analysis of any correlation between  two variables or attributes. It will provide quantitative description about the relation between 2 variables.
#
#
# **Let's check the distribution for numerical columns.**
#
# To check the relation between two vairables, I grouped the qualitiative variables and quantitative variable and measure the mean of each relation.

# %%
data.groupby(['Gender','Product'])['Income'].mean()
# Out:
# Gender  Product
# Female  TM195      46020.075000
#         TM498      49336.448276
#         TM798      73633.857143
# Male    TM195      46815.975000
#         TM498      48634.258065
#         TM798      75825.030303
# Name: Income, dtype: float64

# %% [markdown]
# *   The gender is related to the income. It shows the female and male who bought TM195 are approximatly have the same mean income. Females who bought TM498 have more income than the males who bought the same product. Males who bought TM798 have more income than the females who bought TM798.

# %%
data.groupby(['MaritalStatus','Product'])['Income'].mean()
# Out:
# MaritalStatus  Product
# Partnered      TM195      47848.750000
#                TM498      49522.666667
#                TM798      82047.173913
# Single         TM195      44271.937500
#                TM498      48150.125000
#                TM798      66504.588235
# Name: Income, dtype: float64

# %% [markdown]
# *   Partnereds have high mean than single for each product.
# *   the income increases if the marital status is partnered.
# *   The customers who are partnered and bought TM195 have more income than Single who bought the same product. The same thing for the other product.

# %%
data.groupby(['Age', 'Product'])['Income'].mean()
# Out:
# Age  Product
# 18   TM195       29562.0
# 19   TM195       31836.0
#      TM498       31836.0
# 20   TM195       34110.0
#      TM498       35247.0
#                   ...
# 47   TM195       56850.0
#      TM798      104581.0
# 48   TM498       57987.0
#      TM798       95508.0
# 50   TM195       64809.0
# Name: Income, Length: 68, dtype: float64

# %% [markdown]
# *   The income is not depending on the age. And also the product it is not depending on the age.
# *   There is a little bit of high income for higher ages

# %%
data.groupby(['Education','Product'])['Income'].mean()
# Out:
# Education  Product
# 12         TM195      38658.000000
#            TM498      32973.000000
# 13         TM195      36763.000000
#            TM498      50028.000000
# 14         TM195      44608.300000
#            TM498      43156.565217
#            TM798      67282.000000
# 15         TM195      34678.500000
#            TM498      67083.000000
# 16         TM195      49065.923077
#            TM498      52668.774194
#            TM798      69389.000000
# 18         TM195      67651.500000
#            TM498      56487.000000
#            TM798      80186.315789
# 20         TM798      74701.000000
# 21         TM798      81341.000000
# Name: Income, dtype: float64

# %% [markdown]
# *   The income is depending on the education
#
# *   The income average is increasing if the years of educations incrases
#
# *   The mean is somehow growing up by the number of educational years.
# *   The mean decreased in the 15 number of educational years. Otherwise, it is increased
#
# *   The highest average income customers bought TM798. And Also, they got the highest number of education years. TM798 is used with the customers who have high income with high education years.

# %%
data.groupby(['Product'])['Income'].mean()
# Out:
# Product
# TM195    46418.025
# TM498    48973.650
# TM798    75441.575
# Name: Income, dtype: float64

# %%
data.groupby(['Miles','Product'])['Income'].mean()
# Out:
# Miles  Product
# 21     TM498      65220.000000
# 38     TM195      45480.000000
# 42     TM498      46617.000000
# 47     TM195      47122.333333
# 53     TM498      44018.142857
# 56     TM195      49270.000000
# 64     TM498      46617.000000
# 66     TM195      46503.300000
# 74     TM498      49649.000000
# 75     TM195      43660.800000
# 80     TM798      57271.000000
# 85     TM195      47114.437500
#        TM498      52508.727273
# 94     TM195      48606.750000
# 95     TM498      50880.750000
# 100    TM798      68120.285714
# 103    TM195      46996.000000
# 106    TM498      47611.875000
#        TM798      48658.000000
# 112    TM195      29562.000000
# 113    TM195      45195.750000
# 120    TM798      69721.000000
# 127    TM498      49573.200000
# 132    TM195      51733.500000
# 140    TM798      58516.000000
# 141    TM195      40932.000000
# 150    TM798      96177.250000
# 160    TM798      77938.000000
# 169    TM195      51165.000000
# ...

# %% [markdown]
# * Higher numbers of run miles is for TM798 product.
# * Good runners are using TM798 product. After TM798 it will be TM195 for more frequent used. And then TM498.

# %%
data.groupby(['Product'])[['Income']].median() # find the median for each product with customers income
# Out:
#           Income
# Product
# TM195    46617.0
# TM498    49459.5
# TM798    76568.5

# %%
data.groupby(['Product'])[['Income']].mean()  # find the mean for each product with customers income
# Out:
#             Income
# Product
# TM195    46418.025
# TM498    48973.650
# TM798    75441.575

# %% [markdown]
# * Higher median for TM798 product. And also for the mean.
# * This means that the diagram will be a little bit skweed to the left. But in general the it is normal distribution.
# * Uses for TM798 is more than the other products.

# %% [markdown]
# Find the heat map that find the correlation between each numerical variables with the other variables.

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(),annot=True,cmap='Spectral',vmin=-1,vmax=1)
plt.show()

# %% [markdown]
# Observations
#
# No Negative correlation for all the different numerical variables. This indicates as the variable increases the other variables will increase.
#
# Age column has high correlation with Income and then with Education. This indicates that older customers, have more incomes.
#
# Education column shows high correlation with income which is expected, the people with more income have more years of education.
#
#
# Usage column has the second highest score with Miles.
#
# The highest score is for Fitness with Miles which is expected. The highest fitness means more miles to run.

# %%
plt.figure(figsize=(10,5)) # to show the figure more bigger
sns.scatterplot(data=data,x='Age',y='Income') # to draw the plot

# %% [markdown]
# *   The scatter graph shows that the Age column and Income column are positively correlated
# *   If the Age increased the Income will increased

# %%
plt.figure(figsize=(10,5)) # to show the figure more bigger
sns.lmplot(data=data,x='Age',y='Income',height=5,aspect=2)
plt.xlim(0,55)
plt.show()

# %%
plt.figure(figsize=(10,5)) # to show the figure more bigger
sns.lineplot(data=data, x='Age', y ='Income',ci=None)
plt.show()

# %%
# lets check the correlation between Total space and Price
data[['Age','Income']].corr()
# Out:
#              Age    Income
# Age     1.000000  0.513414
# Income  0.513414  1.000000

# %% [markdown]
# The corrlation between Age and Income is about 51%.

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=data, x='Age', y ='Fitness')
plt.show()

# %% [markdown]
# *   This plot observes that most of the customer in all different ages rank their fitness by 3 out of 5.
# *   It is also observes that less number of customer ranked their fitness by 1 out of 5. And also, this data set has less information about elder people.
# *   Most of the customers are between 20 and 35.

# %%
#plt.figure(figsize=(15,7))
sns.lineplot(data=data, x='Age', y ='Fitness')
plt.show()

# %% [markdown]
# Figure shows a vertical line plot between Age and Fitness, the range of the fitness between all ages is 2.5 till 4.

# %%
sns.boxplot(data=data,x='Product',y='Income')
plt.show()

# %% [markdown]
# Product TM798 is mostly used and it used from customers who have income more thank 60k. TM195 is the second mostly used productfor customers who have income less thank 55k and above 30k. TM498 is used mostly form customers who have income less than 52k and more than 41k.

# %%
sns.boxplot(data=data,x='Product',y='Age')
plt.show()

# %% [markdown]
# TM798 is used mostly from customers in age more than 25 and 30 or less. Rather than the other two products mostly used for ages more than 30 . The customers who are more than 40 and use TM798 considered as outliers

# %%
sns.relplot(data=data,x='Age',y='Income',col='Product',kind='line', ci=None, col_wrap=4)
plt.show()

# %% [markdown]
# The figure shows that Product TM798 is used from age more than 20 with income 50k and increase till age 30 and increase again till age 40 and then increase till age 50. Product TM798 is used from higher income customers, rather than product TM498 and product TM195 used from customers will less income ( less than 60k ) for all ages.

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=data,x='Gender',y='Age')
plt.show()

# %% [markdown]
# Find that male and female approximatly have the same customer age. only one outlier for female in age 50. But the major is from 24 and less than 35 who are using the products

# %% [markdown]
# **Find the age for each product using violin plot**

# %%
# Dispersion of Age for each product
sns.catplot(x='Age',
            col='Product', 
            data=data,
            col_wrap=4,
            kind="violin")
plt.show()

# %%
sns.violinplot(data= data, x='Product', y='Usage',size=8)
plt.show()

# %%
sns.violinplot(data= data, x='Product', y='Education',size=8)
plt.show()

# %% [markdown]
# Find that TM798 is the mostly used product in the education and also in the usage attributes.

# %%
#pairwise scatter plot
#3D plot can be used to show  number of features togather
sns.pairplot(data,hue='Product',size=3);
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Observations for products:
#
#
# *   TM798 is mostly used for customers who are in age 18-35.
# *   TM798 is mostly used for customers who have highest years of education.
# *   TM798 is mostly used for miles from 100 miles to 200 miles.
# *   TM798 is used from the customers who have lower income.
# *   TM798 is used for the customers who rate their fitness lower than the other products.
# *   TM798 mostly used form the customers who used it more than 4 times.
# *   TM195 got by the customers form age 20 till age 50. The miles for this product are from 0 to 350 miles.
# *   TM195 got from customers who have education years from 14- 16. It also got from all ages.
#
# *   TM498 got from customers who are 40 or less. It also got from good education customers. It also got from all fitness customers.

# %% [markdown]
# # Recommendations
#
# * I recommend to Maximize the selling of product TM798 between the customers who have higher education , higher income, higher fitness and age less than 35, .
#
# * I recommend to sell product TM195 for customers who have low income ( less than 60K ) in all ages.
#
# * I recommend to sell product TM498 for the customers who use it 3 times or less, salary less than 70k, age less than 50, education less than 18 years, fitness 4 or less, and run less than 259 miles.
#
#
# * And I also recommend to provide the price of each product to enhance the recommendations.
